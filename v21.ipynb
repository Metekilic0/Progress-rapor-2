# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
import os
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

#Bu sefer 4 tane sınıflandırma classı var kuş,drone,helikopter ve uçak olarak
BASE_PATH = "C:/Users/mkasl/Desktop/donem5/yap470/Ara_rapor_ 1/dataset4"
TRAIN_PATH = os.path.join(BASE_PATH, 'train')
VALID_PATH = os.path.join(BASE_PATH, 'valid')
TEST_PATH = os.path.join(BASE_PATH, 'test')
IMAGE_SIZE = (224, 224) #Çözünürlük daha yüksek.
BATCH_SIZE = 32
tf.random.set_seed(42) #aynı sonucu vermesi için bunu gerçi dosyalara test train valid olarak ayırıyoruz
#tekrarlanabilirliği sağlıyor
EPOCHS = 30 

#Veri setlerini yükleyip hazırlama categorical olması için one hot encoding yapıyorum
train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_PATH, labels='inferred', label_mode='categorical',
    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE, shuffle=True, seed=42)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    VALID_PATH, labels='inferred', label_mode='categorical',
    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE, shuffle=False)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    TEST_PATH, labels='inferred', label_mode='categorical',
    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE, shuffle=False)
class_names = train_dataset.class_names


#Burası cache gibi önbellekleme vs. kullanıp performansı arttırmaya çalıştığım kısım ama buna rağmen daha farklı şeylere
#ihtiyacım var prefecthi sonraki batchi hazırlar cache önbelleğe alır
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

model = tf.keras.Sequential(name="V21_Model")
model.add(tf.keras.layers.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)))
#1. Blok
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
#2. Blok
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
#3. Blok
model.add(tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2)))
#4. Blok
model.add(tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', name="conv4"))
model.add(tf.keras.layers.BatchNormalization(name="bn4"))
model.add(tf.keras.layers.MaxPooling2D((2, 2), name="pool4"))
#5. Blok
model.add(tf.keras.layers.Conv2D(512, (3, 3), activation='relu', padding='same', name="conv5"))
model.add(tf.keras.layers.BatchNormalization(name="bn5"))
model.add(tf.keras.layers.MaxPooling2D((2, 2), name="pool5"))
#GlobalAveragePooling2D ile sınıflandırma eskiden burasında flatten ve dense katmanı vardı
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))
model.summary()

#Bu modelimde değiştirdiğim kısım
#Veri setindeki dosya sayılarını buluyorum ardından sınıfları sayıya göre ağırlıklandırıyorum
class_counts = {}
total_train_samples = 0
for class_name in class_names:
    count = len(os.listdir(os.path.join(TRAIN_PATH, class_name)))
    class_counts[class_name] = count
    total_train_samples += count
#Ağırlıkları hesaplama
class_weights = {}
num_classes = len(class_names)
for i, class_name in enumerate(class_names):
    #Eğer bir sınıfta 0 resim varsa hatayı önlemek ağırlığını 1 yapıyorum
    if class_counts[class_name] == 0:
        weight = 1
    else:
        weight = (1 / class_counts[class_name]) * (total_train_samples / num_classes)
    class_weights[i] = weight

#default olan adam optimizer kullanıyorum
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#EarlyStopping, Checkpoint ve Dinamik öğrenme callbackleri v10 modelimden dinamik öğrenme
callbacks = [
    # patience=5 olarak güncelledim öğrenme oranına ve sınıflandırmaya adapte olması için
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True),
    ModelCheckpoint(filepath='best_4class_model.keras', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1, min_lr=1e-6)
]
#history
history = model.fit(
  train_dataset,
  validation_data=validation_dataset,
  epochs=EPOCHS,
  callbacks=callbacks,
  class_weight=class_weights
)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
actual_epochs = len(acc) 
epochs_range = range(actual_epochs) #X eksenini dinamik olarak ayarlıyorum.
test_loss, test_accuracy = model.evaluate(test_dataset) #accuracy hesaplama 
print(f"\nTest Seti Doğruluğu: {test_accuracy:.4f}")
print(f"Test Seti Kaybı: {test_loss:.4f}")
# Karmaşıklık matrisi
y_pred_probs = model.predict(test_dataset)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true_labels = np.concatenate([y for x, y in test_dataset], axis=0)
y_true = np.argmax(y_true_labels, axis=1)
#Test setindeki tüm resimler için tahminleri al
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Karmaşıklık Matrisi')
plt.ylabel('Gerçek Etiket')
plt.xlabel('Tahmin Edilen Etiket')
plt.show()
# Out:
# Found 15346 files belonging to 4 classes.
# Found 4389 files belonging to 4 classes.
# Found 2185 files belonging to 4 classes.
# Model: "V21_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn4 (BatchNormalization)        │ (None, 28, 28, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling2D)            │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5 (Conv2D)                  │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn5 (BatchNormalization)        │ (None, 14, 14, 512)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool5 (MaxPooling2D)            │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,574,596 (6.01 MB)
#  Trainable params: 1,572,612 (6.00 MB)
#  Non-trainable params: 1,984 (7.75 KB)
# Epoch 1/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6331 - loss: 0.9680
# Epoch 1: val_loss improved from inf to 0.74936, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 821s 2s/step - accuracy: 0.6332 - loss: 0.9676 - val_accuracy: 0.6639 - val_loss: 0.7494 - learning_rate: 0.0010
# Epoch 2/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7838 - loss: 0.5422
# Epoch 2: val_loss did not improve from 0.74936
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 853s 2s/step - accuracy: 0.7838 - loss: 0.5421 - val_accuracy: 0.4944 - val_loss: 1.5542 - learning_rate: 0.0010
# Epoch 3/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8442 - loss: 0.4181
# Epoch 3: val_loss did not improve from 0.74936
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 771s 2s/step - accuracy: 0.8442 - loss: 0.4180 - val_accuracy: 0.5432 - val_loss: 1.2559 - learning_rate: 0.0010
# Epoch 4/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9141 - loss: 0.2501
# Epoch 4: val_loss improved from 0.74936 to 0.25066, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.9142 - loss: 0.2500 - val_accuracy: 0.9036 - val_loss: 0.2507 - learning_rate: 2.0000e-04
# Epoch 5/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9367 - loss: 0.1887
# Epoch 5: val_loss did not improve from 0.25066
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 695s 1s/step - accuracy: 0.9367 - loss: 0.1886 - val_accuracy: 0.9032 - val_loss: 0.2546 - learning_rate: 2.0000e-04
# Epoch 6/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9523 - loss: 0.1463
# Epoch 6: val_loss improved from 0.25066 to 0.18975, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 659s 1s/step - accuracy: 0.9523 - loss: 0.1462 - val_accuracy: 0.9296 - val_loss: 0.1898 - learning_rate: 2.0000e-04
# Epoch 7/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9642 - loss: 0.1108
# Epoch 7: val_loss improved from 0.18975 to 0.14037, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.9642 - loss: 0.1108 - val_accuracy: 0.9517 - val_loss: 0.1404 - learning_rate: 2.0000e-04
# Epoch 8/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9733 - loss: 0.0833
# Epoch 8: val_loss improved from 0.14037 to 0.12702, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 648s 1s/step - accuracy: 0.9733 - loss: 0.0833 - val_accuracy: 0.9608 - val_loss: 0.1270 - learning_rate: 2.0000e-04
# Epoch 9/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9831 - loss: 0.0615
# Epoch 9: val_loss did not improve from 0.12702
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 652s 1s/step - accuracy: 0.9831 - loss: 0.0615 - val_accuracy: 0.9476 - val_loss: 0.1596 - learning_rate: 2.0000e-04
# Epoch 10/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9868 - loss: 0.0468
# Epoch 10: val_loss improved from 0.12702 to 0.09767, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 654s 1s/step - accuracy: 0.9868 - loss: 0.0468 - val_accuracy: 0.9727 - val_loss: 0.0977 - learning_rate: 2.0000e-04
# Epoch 11/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9859 - loss: 0.0498
# Epoch 11: val_loss did not improve from 0.09767
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 655s 1s/step - accuracy: 0.9859 - loss: 0.0498 - val_accuracy: 0.9560 - val_loss: 0.1295 - learning_rate: 2.0000e-04
# Epoch 12/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 0.0325
# Epoch 12: val_loss did not improve from 0.09767
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 649s 1s/step - accuracy: 0.9915 - loss: 0.0325 - val_accuracy: 0.8952 - val_loss: 0.4123 - learning_rate: 2.0000e-04
# Epoch 13/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9936 - loss: 0.0251
# Epoch 13: val_loss improved from 0.09767 to 0.08276, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 634s 1s/step - accuracy: 0.9936 - loss: 0.0251 - val_accuracy: 0.9825 - val_loss: 0.0828 - learning_rate: 4.0000e-05
# Epoch 14/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9972 - loss: 0.0115
# Epoch 14: val_loss improved from 0.08276 to 0.08124, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 656s 1s/step - accuracy: 0.9972 - loss: 0.0115 - val_accuracy: 0.9820 - val_loss: 0.0812 - learning_rate: 4.0000e-05
# Epoch 15/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9987 - loss: 0.0092
# Epoch 15: val_loss improved from 0.08124 to 0.08047, saving model to best_4class_model.keras
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 650s 1s/step - accuracy: 0.9987 - loss: 0.0092 - val_accuracy: 0.9827 - val_loss: 0.0805 - learning_rate: 4.0000e-05
# Epoch 16/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - loss: 0.0081
# Epoch 16: val_loss did not improve from 0.08047
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 643s 1s/step - accuracy: 0.9991 - loss: 0.0081 - val_accuracy: 0.9820 - val_loss: 0.0836 - learning_rate: 4.0000e-05
# Epoch 17/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9995 - loss: 0.0057
# Epoch 17: val_loss did not improve from 0.08047
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 651s 1s/step - accuracy: 0.9995 - loss: 0.0057 - val_accuracy: 0.9829 - val_loss: 0.0876 - learning_rate: 4.0000e-05
# Epoch 18/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - loss: 0.0056
# Epoch 18: val_loss did not improve from 0.08047
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 644s 1s/step - accuracy: 0.9991 - loss: 0.0056 - val_accuracy: 0.9831 - val_loss: 0.0819 - learning_rate: 8.0000e-06
# Epoch 19/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9998 - loss: 0.0043
# Epoch 19: val_loss did not improve from 0.08047
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 632s 1s/step - accuracy: 0.9998 - loss: 0.0043 - val_accuracy: 0.9834 - val_loss: 0.0813 - learning_rate: 8.0000e-06
# Epoch 20/30
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9997 - loss: 0.0042
# Epoch 20: val_loss did not improve from 0.08047
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 665s 1s/step - accuracy: 0.9997 - loss: 0.0042 - val_accuracy: 0.9834 - val_loss: 0.0813 - learning_rate: 1.6000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 223ms/step - accuracy: 0.9809 - loss: 0.0644
#
# Test Seti Doğruluğu: 0.9817
# Test Seti Kaybı: 0.0673
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step
